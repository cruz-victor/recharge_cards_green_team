# %% [markdown]
# <div style="text-align:center;">
#     <h3 style="font-weight: bold; color: white; font-size: 30px">PROCESO FINETUNNING YOLOv8 (ENTEL, TIGO, VIVA)</h3>
# </div>

# %%
import torch # type: ignore
print('GPU disponible=', torch.cuda.is_available())

# %%
import ultralytics # type: ignore
from ultralytics import YOLO # type: ignore

print(ultralytics.__version__)
# Out:
# WARNING  Python>=3.10 is required, but Python==3.9.0 is currently installed
# 8.3.15

# %%
model = YOLO('yolov8n.pt')
data_path=r'C:\Users\VIC\Downloads\DELVE DEEP LEARNING\PROYECTO_TARJETAS\proyecto_jupyter\data\data.yaml'
result=model.train(data=data_path, epochs=20, imgsz=640, batch=16, lr0=0.001)
# Out:
# New https://pypi.org/project/ultralytics/8.3.16 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.15  Python-3.9.0 torch-2.5.0+cu124 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...
